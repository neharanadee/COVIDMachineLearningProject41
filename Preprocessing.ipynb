# %%
import pandas as pd

# %%
hospital_bed_dataset = pd.read_csv('usa-hospital-beds_dataset_usa-hospital-beds.csv')
counties_dataset = pd.read_csv('us-counties.csv')
states_dataset = pd.read_csv('us-states.csv')

# %%
hospital_bed_dataset.head(10)
# Out:
#             X          Y  OBJECTID  \
# 0 -112.066157  33.495498         1
# 1 -110.965885  32.181263         2
# 2 -119.779742  36.773323         3
# 3  -72.957610  41.284400         4
# 4  -75.606533  39.740206         5
# 5  -77.011195  38.930682         6
# 6  -82.345254  29.636989         7
# 7 -116.190185  43.621035         8
# 8  -93.721683  32.503101         9
# 9  -90.105308  32.325487        10
#
#                                        HOSPITAL_NAME  \
# 0  Phoenix VA Health Care System (AKA Carl T Hayd...
# 1             Southern Arizona VA Health Care System
# 2           VA Central California Health Care System
# 3  VA Connecticut Healthcare System - West Haven ...
# 4                       Wilmington VA Medical Center
# 5                    Washington DC VA Medical Center
# 6  North Florida/South Georgia Veterans Health Sy...
# 7                            Boise VA Medical Center
# 8                   Overton Brooks VA Medical Center
# ...

# %%
counties_dataset.head(10)
# Out:
#          date       county       state     fips  cases  deaths
# 0  2020-01-21    Snohomish  Washington  53061.0      1       0
# 1  2020-01-22    Snohomish  Washington  53061.0      1       0
# 2  2020-01-23    Snohomish  Washington  53061.0      1       0
# 3  2020-01-24         Cook    Illinois  17031.0      1       0
# 4  2020-01-24    Snohomish  Washington  53061.0      1       0
# 5  2020-01-25       Orange  California   6059.0      1       0
# 6  2020-01-25         Cook    Illinois  17031.0      1       0
# 7  2020-01-25    Snohomish  Washington  53061.0      1       0
# 8  2020-01-26     Maricopa     Arizona   4013.0      1       0
# 9  2020-01-26  Los Angeles  California   6037.0      1       0

# %%
unique_counties_dataset = states_dataset.groupby("county")["cases", "deaths"].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-01d4637629da> in <module>
# ----> 1 unique_counties_dataset = states_dataset.groupby("county")["cases", "deaths"].sum()
#
# c:\users\904ne\miniconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5808             group_keys=group_keys,
#    5809             squeeze=squeeze,
# -> 5810             observed=observed,
#    5811         )
#    5812
#
# c:\users\904ne\miniconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     408                 sort=sort,
#     409                 observed=observed,
# --> 410                 mutated=self.mutated,
#     411             )
#     412
#
# ...

# %%
unique_counties_dataset.head()

# %%
unique_counties_dataset.columns

# %%
unique_hospital_beds_dataset = hospital_bed_dataset.groupby("HQ_CITY")["NUM_LICENSED_BEDS"].sum()

# %%
unique_hospital_beds_dataset.head()

# %%
unique_hospital_beds_dataset.columns = ["NUM_LICENSED_BEDS"]

# %%
unique_hospital_beds_dataset.shape

# %%
# currently the problem is that we do not have county-wise data for licensed beds 
# we cannot do state-wise because then the data would only have about 50 rows
